# %% [markdown]
# * Exercise - Roll Dice 10 times (random integer between 1 to 6) and print the total.

# %%
total = 0
for i in range(1, 11):
    v = random.randint(1, 6)
    print(v, end=' ')
    total += v

print(total)
